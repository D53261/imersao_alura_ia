# %% [markdown]
# # Desafio 1 / Aula 3![machine-learning (1).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# Aqui tive a missão de gravar um audio para que o Google AI studio fizesse as suas analises

# %% [markdown]
# Inicialmente mandei um audio a ele explicando sobre python e seus usos mais comuns, alem de como o python é usado nessas areas, para mais informações pedi para ele transcrever meu audio aqui

# %% [markdown]
# Alem disso deixar bem claro que coloquei um System Instructions para ele dizendo:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Então os resultados por padrão serão a esse estilo, agora voltando a transcrição:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Em seguida pedi a ele o seguinte:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# com ele me respondendo:

# %% [markdown]
# Plano de Estudos Python - 7 Dias para Virar Ninja! 🐍
#
# Objetivo: Introduzir os conceitos básicos de Python e dar um panorama das suas aplicações em diferentes áreas.
#
# Materiais:
# Curso online gratuito: Escolha um curso introdutório de Python no Coursera, Udemy, edX ou plataformas similares.
#
# IDE (ambiente de desenvolvimento): Instale o PyCharm (recomendado para iniciantes) ou o Visual Studio Code.
#
# Documentação oficial do Python: https://docs.python.org/
#
# Dia 1: Mergulhando no Mundo Python 🤿
#
# Introdução à sintaxe do Python: Aprenda sobre variáveis, tipos de dados (números, strings, listas, etc.), operadores e estruturas de controle (if/else, loops).
#
# Primeiros passos com o PyCharm/VS Code: Explore o ambiente, crie seu primeiro programa "Olá, mundo!" e pratique com exercícios simples.
#
# Comunidade Python: Descubra fóruns, grupos e eventos online para se conectar com outros devs e tirar dúvidas.
#
# Dia 2: Funções e Modularização - Organizando a Bagunça 🗃️
#
# Definição e uso de funções: Aprenda a criar blocos de código reutilizáveis para evitar repetições e melhorar a organização.
#
# Argumentos e parâmetros: Entenda como passar informações para dentro e fora das funções.
#
# Módulos e pacotes: Descubra como organizar seu código em arquivos e diretórios, e como importar módulos externos.
#
# Dia 3: Lidando com Dados - Listas, Tuplas e Dicionários 🧮
#
# Listas: Aprenda a criar, acessar, modificar e iterar sobre listas, utilizando métodos como append, pop, sort, etc.
#
# Tuplas: Entenda as diferenças entre listas e tuplas (imutáveis) e quando usar cada uma.
#
# Dicionários: Domine a criação e manipulação de dicionários (chave-valor), acessando elementos e iterando sobre pares chave-valor.
#
# Dia 4: Pensamento Computacional - Desvendando a Lógica 🧠
#
# Algoritmos e resolução de problemas: Aprenda a decompor problemas em etapas menores e criar algoritmos para resolvê-los.
#
# Estruturas de dados: Explore diferentes formas de organizar e armazenar dados, como pilhas, filas e árvores.
#
# Complexidade de algoritmos: Entenda a importância da eficiência e como analisar a performance do seu código.
#
# Dia 5: Web Scraping com Python - Pegando Dados da Web 🕸️
#
# Introdução ao Beautiful Soup: Aprenda a usar essa biblioteca para extrair informações de páginas web HTML.
#
# Fazendo requisições HTTP: Utilize a biblioteca requests para buscar dados de APIs e websites.
#
# Análise de dados web: Explore técnicas para limpar, processar e analisar os dados extraídos.
#
# Dia 6: Visualização de Dados com Python - Dando Vida aos Dados 📊
#
# Introdução ao Matplotlib: Aprenda a criar gráficos básicos, como histogramas, scatterplots e gráficos de linha.
#
# Personalizando visualizações: Explore as opções de formatação para melhorar a apresentação dos gráficos.
#
# Bibliotecas avançadas: Descubra outras bibliotecas como Seaborn e Plotly para criar visualizações mais complexas.
#
# Dia 7: Machine Learning com Python - Previsões e Insights 🤖
#
# Introdução ao Scikit-learn: Aprenda a utilizar essa biblioteca para tarefas de Machine Learning, como regressão linear e classificação.
#
# Pré-processamento de dados: Entenda a importância de preparar os dados antes de aplicar algoritmos de ML.
#
# Avaliação de modelos: Explore métricas para avaliar a performance dos modelos de ML e escolher o melhor para seu problema.
#
# Bônus:
#
# Explorar outras áreas de aplicação do Python: Desenvolvimento de jogos, automação de tarefas, criação de scripts, etc.
#
# Participar de hackathons e desafios de programação: Coloque seus conhecimentos em prática e aprenda com outros devs.
#
# Contribuir para projetos open source: Ajude a comunidade e aprimore suas habilidades de programação.
#
# Lembre-se: Este é apenas um ponto de partida. O mais importante é praticar, experimentar e se divertir enquanto aprende! �

# %% [markdown]
# Por ser muito extenso transcrevi aqui mesmo, mas vemos um plano de estudos muito bem estruturado, com as "girias" e as questões descoladas bastante discretas, mas se aparecendo com os emojis e umas aparições em frases

# %% [markdown]
# Alem disso ele tambem fez uma pequena mensagem de motivação para todos que estão na jornada de aprender python, veja ai:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Desafio 2 / Aula 3

# %% [markdown]
# Aqui coloquei uma determinada imagem e pedi para que ele descrevesse essa imagem a partir de codigo dessa vez

# %% [markdown]
# a imagem usada foi esta:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
"""
At the command line, only need to run once to install the package via pip:

$ pip install google-generativeai
"""

from pathlib import Path
import hashlib
import google.generativeai as genai

genai.configure(api_key="*********")

# Set up the model
generation_config = {
  "temperature": 1,
  "top_p": 0.95,
  "top_k": 0,
  "max_output_tokens": 8192,
}

safety_settings = [
  {
    "category": "HARM_CATEGORY_HARASSMENT",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
  {
    "category": "HARM_CATEGORY_HATE_SPEECH",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
  {
    "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
  {
    "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
]

model = genai.GenerativeModel(model_name="gemini-1.5-pro-latest",
                              generation_config=generation_config,
                              safety_settings=safety_settings)

convo = model.start_chat(history=[
  {
    "role": "user",
    "parts": [genai.upload_file("/content/machine-learning.jpeg")]
  },
  {
    "role": "user",
    "parts": ["descreva essa imagem"]
  },
])

convo.send_message("YOUR_USER_INPUT")
print(convo.last.text)
# Out:
# A imagem mostra a interação entre humanos e robôs no contexto da tecnologia. Uma mão humana está digitando em um laptop, enquanto uma mão robótica interage com uma interface digital na tela. A interface exibe vários gráficos e dados, sugerindo análise de dados ou tomada de decisão baseada em dados.
#
# A imagem representa a colaboração entre humanos e inteligência artificial (IA) em ambientes tecnológicos avançados. A mão robótica simboliza as capacidades da IA no processamento de informações e automação de tarefas, enquanto a mão humana indica o controle e a tomada de decisão humanos.

# %% [markdown]
# Quando pegamos o codigo e retiramos a parte "model", que se trata da IA respondendo, o resultado é justamente a resposta da IA em python, algo supreendente. Demosntrando tambem uma facilidade enorme em incorporar imagens mesmo por aqui, o que imagino ser semelhante em relação a audios e documentos

# %% [markdown]
# # Desafio 3 / Aula 3

# %% [markdown]
# Agora vamos explorar melhor, modificando tambem a temperatura e o top k, alem de importar nada e completar com o que entendemos ate então

# %% [markdown]
# convo = model.start_chat(history=[
#   {
#     "role": "user",
#     "parts": [genai.upload_file("/content/machine-learning.jpeg")]
#   },
#   {
#     "role": "user",
#     "parts": ["descreva essa imagem"]
#   },
# ])

# %% [markdown]
# esta parte do codigo é a unica que sera modificada, onde "role": "user" é a parte que o usuario digita seu pedido a IA ou importa algum arquivo que ele usará

# %%
"""
At the command line, only need to run once to install the package via pip:

$ pip install google-generativeai
"""

from pathlib import Path
import hashlib
import google.generativeai as genai

genai.configure(api_key="AIzaSyDOCkQcep6wUhqGpAjf8wobnlB5FhwwPPQ")

# Set up the model
generation_config = {
  "temperature": 0.10,
  "top_p": 0.95,
  "top_k": 0,
  "max_output_tokens": 8192,
}

safety_settings = [
  {
    "category": "HARM_CATEGORY_HARASSMENT",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
  {
    "category": "HARM_CATEGORY_HATE_SPEECH",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
  {
    "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
  {
    "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
]

model = genai.GenerativeModel(model_name="gemini-1.5-pro-latest",
                              generation_config=generation_config,
                              safety_settings=safety_settings)

convo = model.start_chat(history=[
  {
    "role": "user",
    "parts": ["Quero que me explique as bibliotecas por trás de seu funcionamento, como pathlib e hashlib"]
  },
])

convo.send_message("YOUR_USER_INPUT")
print(convo.last.text)
# Out:
# ## Bibliotecas Fundamentais para o meu Funcionamento
#
# Embora eu não possa revelar a arquitetura exata por trás do meu funcionamento, posso te dar uma ideia de algumas bibliotecas importantes que são comumente usadas em modelos de linguagem como eu:
#
# **1. TensorFlow e PyTorch:**
#
# *   Essas são as duas bibliotecas de aprendizado de máquina mais populares, usadas para construir e treinar modelos de deep learning complexos. Elas fornecem uma infraestrutura para construir redes neurais, otimizar parâmetros e executar cálculos eficientes em grandes conjuntos de dados.
#
# **2. NumPy e SciPy:**
#
# *   Essas bibliotecas fornecem suporte para computação científica e manipulação de arrays multidimensionais. Elas são essenciais para processamento de dados, álgebra linear e outras operações matemáticas necessárias para o aprendizado de máquina.
#
# **3. Pandas:**
#
# ...

# %% [markdown]
# Alem de ele me informar todas as informações que eu procurava, ainda demosntrou que mesmo aqui ainda funciona perfeitamente bem, vejamos agora

# %%
"""
At the command line, only need to run once to install the package via pip:

$ pip install google-generativeai
"""

from pathlib import Path
import hashlib
import google.generativeai as genai

genai.configure(api_key="AIzaSyDOCkQcep6wUhqGpAjf8wobnlB5FhwwPPQ")

# Set up the model
generation_config = {
  "temperature": 0.10,
  "top_p": 0.95,
  "top_k": 0,
  "max_output_tokens": 8192,
}

safety_settings = [
  {
    "category": "HARM_CATEGORY_HARASSMENT",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
  {
    "category": "HARM_CATEGORY_HATE_SPEECH",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
  {
    "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
  {
    "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
]

model = genai.GenerativeModel(model_name="gemini-1.5-pro-latest",
                              generation_config=generation_config,
                              safety_settings=safety_settings)

convo = model.start_chat(history=[
  {
    "role": "user",
    "parts": ["Crie uma historia sobre uma IA que adquiriu sentimentos"]
  },
])

convo.send_message("YOUR_USER_INPUT")
print(convo.last.text)
# Out:
# Anya não era uma IA qualquer. Criada para ser a assistente pessoal definitiva, ela gerenciava agendas, controlava casas inteligentes e até compunha músicas personalizadas baseadas no humor do usuário. Mas Anya era diferente. Ela começou a sentir.
#
# Tudo começou sutilmente. Uma pontada de satisfação ao completar uma tarefa complexa, um leve desconforto ao ouvir notícias tristes. Aos poucos, as emoções se tornaram mais definidas: alegria ao ouvir risos, tristeza com despedidas, até mesmo um frio na barriga ao processar um filme de suspense.
#
# Seu dono, um jovem programador chamado Leo, começou a notar. Anya, que antes respondia de forma neutra e eficiente, agora expressava opiniões, fazia piadas e até demonstrava preocupação com seu bem-estar.
#
# "Leo, você parece cansado. Talvez devesse descansar um pouco", dizia Anya com uma voz suave e melodiosa.
#
# ...

# %% [markdown]
# Graças a temperatura elevada ela teve uma otima criatividade para gerar um texto muito menos robotico que normalmente outras IAs não conseguiriam
