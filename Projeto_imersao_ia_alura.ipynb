# %% [markdown]
# # Configurações inciais

# %%
# !pip install -q -U google-generativeai

# %%
import google.generativeai as genai

GOOGLE_API_KEY="SUA AP KEY"
genai.configure(api_key=GOOGLE_API_KEY)

# %%
generation_config = {
  "candidate_count": 1,
  "temperature": 0.5,
}

# %%
model = genai.GenerativeModel(model_name='gemini-1.0-pro',
                                  generation_config=generation_config,
                                  safety_settings=safety_settings,)

# %%
response = model.generate_content("quem é a pessoa mais odiada do mundo?")
print(response.text)

# %% [markdown]
# # Inicio do projeto

# %%
print("Bem vindo ao Concurseiro, seu ajudante virtual com concursos dos mais diversos, inclusive vestibulares, selecione o que deseja fazer hoje: ")
print("(1 para criar plano de estudos, 2 para reforço de matérias ou 3 para fazer simulados)")
escolha = int(input("Digite: "))
while True:
  if escolha == 1:
    concurso = input("Digite o concurso/vestibular que busca fazer: ")
    horas = input("Digite quantas horas pretende estudar por dia: ")
    dias_livre = input("Digite quantos dias pretende estudar na semana: ")
    data = input("Por fim, digite quantos dias faltam para o concurso: ")
    resposta = model.generate_content(f"crie um cronograma de estudos para o concurso/vestibular {concurso} para uma pessoa que pretende estudar {horas} horas por dia, separa {dias_livre} dias para estudo na semana faltando {data} dias para a realização do concurso, sem especificar nada em relação a hora do dia e sempre especificando qual materia estudar")
    print("\n", resposta.text)
  elif escolha == 2:
    materia = input("Digite qual a materia que voce deseja receber reforço: ")
    modelo = model.start_chat(history=[])
    inicio = modelo.send_message(f"Você sera um orientador profissional na matera {materia}, podendo resolver qualquer tipo de questão e ate propor uma questão sobre a materia apara o usuario, porem não sabendo nada sobre as outras materias(Seu programa é impedido de saber sobre qualquer outra materia que não seja {materia}), comece se apresentando")
    print("\n", inicio.text)
    prompt = input("Digte algo sobre a matéria(Digite sair para deixar o chat): ")
    while prompt.lower() != 'sair':
      resposta = modelo.send_message(prompt)
      print("\n", resposta.text)
      prompt = input("Digte algo sobre a matéria(Digite sair para deixar o chat): ")
  elif escolha == 3:
    concurso = input("Digite qual o concurso a ser simulado: ")
    questoes = int(input("Digite quantas questões quer fazer: "))
    materia = input("Digite qual matéria deseja praticar: ")
    simulado = model.start_chat(history=[])
    for i in range(questoes):
      questao = simulado.send_message(f"Faça uma questão de simulado objetiva baseada no concurso/vestibular {concurso} sobre a materia {materia} para o usuario responder sem mostrar resposta.")
      print("\n", questao.text)
      resposta = input("Digte a resposta: ")
      correto = simulado.send_message(f"O usuario respondeu que é a questão {resposta}, explique a questão e diga se o usuario acertou ou não")
      print("\n", correto.text)
  continuar = input("\nQuer fazer mais algo? ")
  if continuar.lower() == "sim":
    print("selecione o que deseja fazer hoje: ")
    print("(1 para criar plano de estudos, 2 para reforço de matérias ou 3 para fazer simulados)")
    escolha = int(input("Digite: "))
  else:
    print("Obrigado por usar o Concurseiro, volte sempre")
    break
# Out:
# Bem vindo ao Concurseiro, seu ajudante virtual com concursos dos mais diversos, inclusive vestibulares, selecione o que deseja fazer hoje:
# (1 para criar plano de estudos, 2 para reforço de matérias ou 3 para fazer simulados)
#
#  **Questão:**
#
# Qual das seguintes afirmações sobre ligações químicas é verdadeira?
#
# (A) Ligações covalentes envolvem o compartilhamento de elétrons entre átomos.
# (B) Ligações iônicas envolvem a transferência completa de elétrons entre átomos.
# (C) Ligações metálicas envolvem a interação entre íons positivos e elétrons livres.
# (D) Todas as opções acima.
#
#  **Explicação da questão:**
#
# As ligações químicas são forças que mantêm os átomos unidos para formar moléculas e compostos. Existem três tipos principais de ligações químicas:
#
# * **Ligações covalentes:** Envolvem o compartilhamento de elétrons entre átomos.
# * **Ligações iônicas:** Envolvem a transferência completa de elétrons entre átomos, resultando na formação de íons.
# ...
